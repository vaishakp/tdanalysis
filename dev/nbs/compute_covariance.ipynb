# %%
import numpy as np
import matplotlib.pyplot as plt
from TimeDomainAnalysis import CovarianceCalculator
import config

config.conf_matplolib()
# Out:
# /home/vaishakprasad/Documents/Projects/Codes/custom_libraries/waveformtools/waveformtools
# No module named 'pycbc'

# %%
help(CovarianceCalculator)
# Out:
# Help on class CovarianceCalculator in module TimeDomainAnalysis:
#
# class CovarianceCalculator(builtins.object)
#  |  CovarianceCalculator(ref_gps_time=None, sampling_frequency=4096, correlation_duration=4, n_cov=10, noise_sampling_range=100, gps_time_exclusion_duration=8, auto_corr_method='median', detector='L1', analysis_duration=1)
#  |
#  |  Carry out time-domain analysis of data.
#  |
#  |  Given a gps reference time, this allows
#  |
#  |  1.  Computation of the autocorrelation function of specified length.
#  |      This will be computed as either the median or mean over `n_cov`
#  |      auto-correlation frames.
#  |  2.  Construction of the covariance matrix from the autocorrelation function
#  |      assuming a symmetric Toeplez form.
#  |  3.  Inference over the given priors `priors` and `n_live` number of live
#  |      points with a specified model.
#  |
#  |  Methods defined here:
#  |
# ...

# %%
ccalc = CovarianceCalculator(
    ref_gps_time=1126259462,
    noise_sampling_range=512,
    correlation_duration=16,
    n_cov=100,
    gps_time_exclusion_duration=1,
    analysis_duration=0.67333984375,
    auto_corr_method="mean",
)

# %%
ccalc.run()
# Out:
# Computing autocorrelations
# Progress:|#################################################################################################8 |100%

# %%
ccalc.Cij_file_name
# Out:
# 'Cij_gpsT1126259462_R512_D16_S4096_A0.67333984375_N100.npy'

# %%
ccalc.Cij.shape
# Out:
# (2758, 2758)

# %%
plt.plot(ccalc.est_auto_corr)

# %%
plt.plot(ccalc.est_auto_corr)
